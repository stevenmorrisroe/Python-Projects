# %%
import requests
from bs4 import BeautifulSoup
count = 420
Athlete_Name = []
while count >300:
    url = "https://nilcollegeathletes.com/athletes?page="
    url+=str(count)
    response = requests.get(url)

    soup = BeautifulSoup(response.text, 'html.parser')

    links = soup.find_all('a', class_="hover:underline hover:text-blue-700")

    for link in links:
        name = link.text
        Athlete_Name.append(name)
    count-=1
print(Athlete_Name)
# Out:
# ['\n                            Evan Tillinghast\n                          ', '\n                            Dillon Peters\n                          ', '\n                            Kelvin Dennis\n                          ', '\n                            Tommy Tran\n                          ', '\n                            Zocko Littleton Jr\n                          ', '\n                            Kaâ\x80\x99ci Foreman\n                          ', '\n                            Melvin Smalls\n                          ', '\n                            Logan Whitfield\n                          ', '\n                            Amanda Rice\n                          ', '\n                            Connor Printz\n                          ', '\n                            Amire Loftis\n                          ', '\n                            Francisco Liguori\n                          ', '\n                            Aaron Smith\n                          ', '\n                            Connor Willihnganz\n                          ', '\n                            Tierney Schaible\n                          ', '\n                            Dailen Ward\n                          ', '\n                            Samy Shelbaya\n                          ', '\n                            Chase Underhill\n                          ', '\n                            Tyson Guzman\n                          ', '\n                            Michael Menetre\n                          ', '\n                            Tamarick Best\n                          ', '\n                            Reagan Miller\n                          ', '\n                            Ethan Pheifer\n                          ', '\n                            Lexie Allshouse \n                          ', '\n                            Chet Holmgren\n                          ', '\n                            Astoria Beckett\n                          ', '\n                            Lauren Mitra\n                          ', '\n                            Hassan Hall\n                          ', '\n                            Isabella Chugranis\n                          ', '\n                            Mariana Gonzalez\n                          ', '\n                            Kate Ott\n                          ', '\n                            Luke Gomez\n                          ', '\n                            Quincy Reynolds\n                          ', '\n                            Cory Crooks\n                          ', "\n                            Day'Anna Marr\n                          ", '\n                            Alexis Duncan\n                          ', '\n                            Luke Brunette\n                          ', '\n                            Milabella Vasquez\n                          ', '\n                            Chelsea Marstellar\n                          ', '\n                            Brock Dalton\n                          ', '\n                            Dylan Avery\n                          ', '\n                            Will Niebrugge\n                          ', '\n                            Brennan Chavez Potter\n                          ', '\n                            Josie Goodrich\n                          ', '\n                            Bella Kober\n                          ', '\n                            Austin Bressler\n                          ', '\n                            Charlie Brimacombe\n                          ', '\n                            Christian Casto\n                          ', '\n                            Trey Bishop\n                          ', '\n                            Cole Cavenaugh\n                          ', '\n                            Stella Reshetiloff\n                          ', '\n                            Luke Campbell\n                          ', '\n                            Chloe Lee\n      ...
